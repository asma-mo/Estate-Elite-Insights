# %% [markdown]
# <a href="https://colab.research.google.com/github/asma-mo/Estate-Elite-Insights/blob/rahaf_branch/data_cleaning/python_code/population_by_municipality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import pandas as pd
auth.authenticate_user()
project_id="data-analytics-bootcamp-363212"
data="prello"
table="population_by_municipality"
query =  f"SELECT * FROM `{project_id}.{data}.{table}`"
population_by_municipality=pd.read_gbq(query, project_id)
population_by_municipality
# Out:
#        municipality_code  year  population country_code
# 0                  04213  1968         0.0           01
# 1                  05137  1968         0.0           01
# 2                  55039  1968         0.0           01
# 3                  55050  1968         0.0           01
# 4                  55239  1968         0.0           01
# ...                  ...   ...         ...          ...
# 689490             67482  2019    287228.0           01
# 689491             93051  2019     67871.0           01
# 689492             92012  2019    121583.0           01
# 689493             33063  2019    260958.0           01
# 689494             37261  2019    137087.0           01
#
# [689495 rows x 4 columns]

# %% [markdown]
# drop country_code

# %%
# Display the original DataFrame
print("Original DataFrame:")
print(population_by_municipality)

# Drop a column by specifying the column name
column_name = 'country_code'
population_by_municipality = population_by_municipality.drop(column_name, axis=1)

# Display the modified DataFrame
print("Modified DataFrame:")
print(population_by_municipality)
# Out:
# Original DataFrame:
#        municipality_code  year  population country_code
# 0                  04213  1968         0.0           01
# 1                  05137  1968         0.0           01
# 2                  55039  1968         0.0           01
# 3                  55050  1968         0.0           01
# 4                  55239  1968         0.0           01
# ...                  ...   ...         ...          ...
# 689490             67482  2019    287228.0           01
# 689491             93051  2019     67871.0           01
# 689492             92012  2019    121583.0           01
# 689493             33063  2019    260958.0           01
# 689494             37261  2019    137087.0           01
#
# [689495 rows x 4 columns]
# Modified DataFrame:
#        municipality_code  year  population
# 0                  04213  1968         0.0
# 1                  05137  1968         0.0
# 2                  55039  1968         0.0
# 3                  55050  1968         0.0
# ...

# %% [markdown]
# disply the table

# %%
population_by_municipality
# Out:
#        municipality_code  year  population
# 0                  04213  1968         0.0
# 1                  05137  1968         0.0
# 2                  55039  1968         0.0
# 3                  55050  1968         0.0
# 4                  55239  1968         0.0
# ...                  ...   ...         ...
# 689490             67482  2019    287228.0
# 689491             93051  2019     67871.0
# 689492             92012  2019    121583.0
# 689493             33063  2019    260958.0
# 689494             37261  2019    137087.0
#
# [689495 rows x 3 columns]

# %%
import pandas as pd
df=pd.DataFrame(population_by_municipality)

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# municipality_code    0
# year                 0
# population           0
# dtype: int64

# %%
# Check for duplicated rows
duplicated_rows = df[df.duplicated()]

# Display the duplicated rows, if any
print("Duplicated rows:")
print(duplicated_rows)
# Out:
# Duplicated rows:
# Empty DataFrame
# Columns: [municipality_code, year, population]
# Index: []

# %%
# Get the number of unique values in each column
unique_values_per_column = df.nunique()
print("Number of unique values in each column:")
print(unique_values_per_column)
# Out:
# Number of unique values in each column:
# municipality_code    38219
# year                    19
# population           23226
# dtype: int64
