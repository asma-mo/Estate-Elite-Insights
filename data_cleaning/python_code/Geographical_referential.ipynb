# %% [markdown]
# <a href="https://colab.research.google.com/github/asma-mo/Estate-Elite-Insights/blob/najwa_branch/data_cleaning/python_code/Geographical_referential.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Possible outcome:
#
# • Ambiguous columns names has altered
#
# • PK test is done successfully
# • Data types of each column are correct
# • There is no missing Values (NaN Values)
#
# • There is no duplicated rows
# • Unique values of columns are checked
# • Unnecessary columns are dropped

# %%
from google.colab import auth
import pandas as pd
auth.authenticate_user()
project_id="data-analytics-bootcamp-363212"
data="prello"
table="geographical_referential"
query =  f"SELECT * FROM `{project_id}.{data}.{table}`"
geographical_referential=pd.read_gbq(query, project_id)
geographical_referential
# Out:
#       municipality_code            city_name city_name_normalized  \
# 0                 01005  Ambérieux-en-Dombes  AMBERIEUX EN DOMBES
# 1                 01021      Ars-sur-Formans      ARS SUR FORMANS
# 2                 01030           Beauregard           BEAUREGARD
# 3                 01105             Civrieux             CIVRIEUX
# 4                 01157              Fareins              FAREINS
# ...                 ...                  ...                  ...
# 34992             97614             Ouangani             OUANGANI
# 34993             97616                 Sada                 SADA
# 34994             97617             Tsingoni             TSINGONI
# 34995             97608             Dzaoudzi             DZAOUDZI
# 34996             97615             Pamandzi             PAMANDZI
#
#       municipality_type   latitude  longitude department_code    epci_code  \
# 0          municipality  45.996180   4.912273              01  200042497.0
# ...

# %%
import pandas as pd
df= pd.DataFrame(geographical_referential)

# %%
 geographical_referential.rename(columns={'epci_code': 'code_ administrative_services'} , inplace=True)

# %%
print(df)
# Out:
#       municipality_code            city_name city_name_normalized  \
# 0                 01005  Ambérieux-en-Dombes  AMBERIEUX EN DOMBES
# 1                 01021      Ars-sur-Formans      ARS SUR FORMANS
# 2                 01030           Beauregard           BEAUREGARD
# 3                 01105             Civrieux             CIVRIEUX
# 4                 01157              Fareins              FAREINS
# ...                 ...                  ...                  ...
# 34992             97614             Ouangani             OUANGANI
# 34993             97616                 Sada                 SADA
# 34994             97617             Tsingoni             TSINGONI
# 34995             97608             Dzaoudzi             DZAOUDZI
# 34996             97615             Pamandzi             PAMANDZI
#
#       municipality_type   latitude  longitude department_code  \
# 0          municipality  45.996180   4.912273              01
# ...

# %%
# Drop column
df.drop(columns=['country_code'], inplace=True)

# %%
print(df)
# Out:
#       municipality_code            city_name city_name_normalized  \
# 0                 01005  Ambérieux-en-Dombes  AMBERIEUX EN DOMBES
# 1                 01021      Ars-sur-Formans      ARS SUR FORMANS
# 2                 01030           Beauregard           BEAUREGARD
# 3                 01105             Civrieux             CIVRIEUX
# 4                 01157              Fareins              FAREINS
# ...                 ...                  ...                  ...
# 34992             97614             Ouangani             OUANGANI
# 34993             97616                 Sada                 SADA
# 34994             97617             Tsingoni             TSINGONI
# 34995             97608             Dzaoudzi             DZAOUDZI
# 34996             97615             Pamandzi             PAMANDZI
#
#       municipality_type   latitude  longitude department_code  \
# 0          municipality  45.996180   4.912273              01
# ...

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# municipality_code                 0
# city_name                         0
# city_name_normalized              0
# municipality_type                 0
# latitude                          0
# longitude                         0
# department_code                   0
# code_ administrative_services    52
# department_name                   0
# dtype: int64

# %%
# Drop rows with missing values
df_cleaned_rows = df.dropna()

# Display the DataFrame after removing rows with missing values
print("DataFrame after removing rows with missing values:")
print(df_cleaned_rows)
# Out:
# DataFrame after removing rows with missing values:
#       municipality_code            city_name city_name_normalized  \
# 0                 01005  Ambérieux-en-Dombes  AMBERIEUX EN DOMBES
# 1                 01021      Ars-sur-Formans      ARS SUR FORMANS
# 2                 01030           Beauregard           BEAUREGARD
# 3                 01105             Civrieux             CIVRIEUX
# 4                 01157              Fareins              FAREINS
# ...                 ...                  ...                  ...
# 34992             97614             Ouangani             OUANGANI
# 34993             97616                 Sada                 SADA
# 34994             97617             Tsingoni             TSINGONI
# 34995             97608             Dzaoudzi             DZAOUDZI
# 34996             97615             Pamandzi             PAMANDZI
#
#       municipality_type   latitude  longitude department_code  \
# ...

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# municipality_code                0
# city_name                        0
# city_name_normalized             0
# municipality_type                0
# latitude                         0
# longitude                        0
# department_code                  0
# code_ administrative_services    0
# department_name                  0
# dtype: int64

# %%
# Check for duplicated rows
duplicated_rows = df[df.duplicated()]

# Display the duplicated rows, if any
print("Duplicated rows:")
print(duplicated_rows)
# Out:
# Duplicated rows:
# Empty DataFrame
# Columns: [municipality_code, city_name, city_name_normalized, municipality_type, latitude, longitude, department_code, code_ administrative_services, department_name]
# Index: []

# %%
# Get the number of unique values in each column
unique_values_per_column = df.nunique()
print("Number of unique values in each column:")
print(unique_values_per_column)
# Out:
# Number of unique values in each column:
# municipality_code                34945
# city_name                        32692
# city_name_normalized             32474
# municipality_type                    1
# latitude                         34945
# longitude                        34945
# department_code                    100
# code_ administrative_services     1255
# department_name                    100
# dtype: int64
