# %% [markdown]
# <a href="https://colab.research.google.com/github/asma-mo/Estate-Elite-Insights/blob/ran_branch/data_cleaning/python_code/clean_notary_real_estate_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #upload

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Prello/
# Out:
# /content/drive/MyDrive/Prello

# %%
# %ls
# Out:
#  average_salary_by_municipality.csv   POI_tourist_establishments.csv
# 'clean data'/                         POI_touristic_sites_by_municipality.csv
#  estate-elite-insights/               population_by_municipality.csv
#  geographical_referential.csv         poverty_population_by_municipality.csv
#  housing_stock.csv                    real_estate_info_by_municipality.csv
#  notary_real_estate_sales.csv

# %%
import pandas as pd
copied_path = "/content/drive/MyDrive/Prello/notary_real_estate_sales.csv"
df = pd.read_csv(copied_path)

# %% [markdown]
# #cleaning dataframe

# %% [markdown]
# ## changing type

# %%
df.dtypes
# Out:
# sales_date                    object
# sales_amount                 float64
# street_number                float64
# street_code                   object
# street_name                   object
# nom_commune                   object
# municipality_code             object
# premise_type                  object
# surface                        int64
# number_of_principal_rooms      int64
# sales_price_m2                 int64
# latitude                     float64
# longitude                    float64
# dtype: object

# %%
df["sales_date"] = pd.to_datetime(df["sales_date"])

# %%
df.dtypes
# Out:
# sales_date                   datetime64[ns]
# sales_amount                        float64
# street_number                       float64
# street_code                          object
# street_name                          object
# nom_commune                          object
# municipality_code                    object
# premise_type                         object
# surface                               int64
# number_of_principal_rooms             int64
# sales_price_m2                        int64
# latitude                            float64
# longitude                           float64
# dtype: object

# %%
df.head()
# Out:
#   sales_date  sales_amount  street_number street_code            street_name  \
# 0 2018-02-06     5000000.0           63.0        0040  AV PRINCE RAINIER III
# 1 2018-11-26       93060.0         5308.0        B061              LE SERRET
# 2 2018-06-08       95000.0          161.0        0683  IMP COL EMILE VIGUIER
# 3 2018-07-17     3912000.0          690.0        1868       CHE DE MAZARGUES
# 4 2018-03-27      810000.0         5000.0        0162       CHE DES OLIVIERS
#
#                      nom_commune municipality_code premise_type  surface  \
# 0          Saint-Jean-Cap-Ferrat             06121       Maison      292
# 1  Vallées-d'Antraigues-Asperjoc             07011       Maison       16
# 2                         Millau             12145       Maison       21
# 3                Aix-en-Provence             13001       Maison      610
# 4                     Eygalières             13034       Maison      296
#
# ...

# %% [markdown]
# ##renaming columns

# %%
df.rename(columns = {'nom_commune':'city_name'}, inplace = True)

# %%
df.head()
# Out:
#   sales_date  sales_amount  street_number street_code            street_name  \
# 0 2018-02-06     5000000.0           63.0        0040  AV PRINCE RAINIER III
# 1 2018-11-26       93060.0         5308.0        B061              LE SERRET
# 2 2018-06-08       95000.0          161.0        0683  IMP COL EMILE VIGUIER
# 3 2018-07-17     3912000.0          690.0        1868       CHE DE MAZARGUES
# 4 2018-03-27      810000.0         5000.0        0162       CHE DES OLIVIERS
#
#                        city_name municipality_code premise_type  surface  \
# 0          Saint-Jean-Cap-Ferrat             06121       Maison      292
# 1  Vallées-d'Antraigues-Asperjoc             07011       Maison       16
# 2                         Millau             12145       Maison       21
# 3                Aix-en-Provence             13001       Maison      610
# 4                     Eygalières             13034       Maison      296
#
# ...

# %% [markdown]
# ## sorting dataframe by date

# %%
df.sort_values(by="sales_date",ascending=True)
df
# Out:
#         sales_date  sales_amount  street_number street_code  \
# 0       2018-02-06     5000000.0           63.0        0040
# 1       2018-11-26       93060.0         5308.0        B061
# 2       2018-06-08       95000.0          161.0        0683
# 3       2018-07-17     3912000.0          690.0        1868
# 4       2018-03-27      810000.0         5000.0        0162
# ...            ...           ...            ...         ...
# 4331935 2017-11-10      160000.0         9001.0        A055
# 4331936 2019-03-15      290000.0         9001.0        A278
# 4331937 2018-04-26      540000.0         9001.0        A370
# 4331938 2021-08-25      184000.0         9001.0        0002
# 4331939 2021-08-31      610000.0         9001.0        A155
#
#                            street_name                      city_name  \
# 0                AV PRINCE RAINIER III          Saint-Jean-Cap-Ferrat
# 1                            LE SERRET  Vallées-d'Antraigues-Asperjoc
# ...

# %% [markdown]
# ##checking for duplactes

# %%
df.duplicated(keep='first').sum()
# Out:
# 510211

# %%
df.shape
# Out:
# (4331940, 13)

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (3821729, 13)

# %%
df.head()
# Out:
#   sales_date  sales_amount  street_number street_code            street_name  \
# 0 2018-02-06     5000000.0           63.0        0040  AV PRINCE RAINIER III
# 1 2018-11-26       93060.0         5308.0        B061              LE SERRET
# 2 2018-06-08       95000.0          161.0        0683  IMP COL EMILE VIGUIER
# 3 2018-07-17     3912000.0          690.0        1868       CHE DE MAZARGUES
# 4 2018-03-27      810000.0         5000.0        0162       CHE DES OLIVIERS
#
#                        city_name municipality_code premise_type  surface  \
# 0          Saint-Jean-Cap-Ferrat             06121       Maison      292
# 1  Vallées-d'Antraigues-Asperjoc             07011       Maison       16
# 2                         Millau             12145       Maison       21
# 3                Aix-en-Provence             13001       Maison      610
# 4                     Eygalières             13034       Maison      296
#
# ...

# %% [markdown]
# ##checking null values

# %%
df.isnull().sum()
# Out:
# sales_date                       0
# sales_amount                     0
# street_number                22830
# street_code                      0
# street_name                     52
# city_name                        0
# municipality_code                0
# premise_type                     0
# surface                          0
# number_of_principal_rooms        0
# sales_price_m2                   0
# latitude                     49502
# longitude                    49502
# dtype: int64

# %% [markdown]
# ##table unique values

# %%
df.shape
# Out:
# (3821729, 13)

# %%
pd.value_counts(df.sales_date)
# Out:
# 2020-05-29    9755
# 2021-07-30    9660
# 2020-12-18    9035
# 2021-06-30    9024
# 2021-04-30    8401
#               ...
# 2021-06-20       1
# 2018-04-15       1
# 2021-08-29       1
# 2020-11-08       1
# 2020-04-05       1
# Name: sales_date, Length: 1604, dtype: int64

# %%
pd.value_counts(df.street_code)
# Out:
# 0020    28514
# 0040    27650
# 0060    25554
# 0100    22199
# 0080    21972
#         ...
# H322        1
# H365        1
# V427        1
# J682        1
# 9565        1
# Name: street_code, Length: 15597, dtype: int64

# %%
pd.value_counts(df.municipality_code)
# Out:
# 31555      40680
# 06088      37649
# 44109      28061
# 33063      24397
# 34172      24321
#            ...
# 74310.0        1
# 80046          1
# 70440          1
# 10079          1
# 39298          1
# Name: municipality_code, Length: 33395, dtype: int64

# %%
pd.value_counts(df.premise_type)
# Out:
# Maison         2177488
# Appartement    1644241
# Name: premise_type, dtype: int64

# %% [markdown]
# #importing the file to csv

# %%
# %ls
# Out:
#  average_salary_by_municipality.csv   POI_tourist_establishments.csv
# 'clean data'/                         POI_touristic_sites_by_municipality.csv
#  estate-elite-insights/               population_by_municipality.csv
#  geographical_referential.csv         poverty_population_by_municipality.csv
#  housing_stock.csv                    real_estate_info_by_municipality.csv
#  notary_real_estate_sales.csv

# %%
# %cd /content/drive/MyDrive/Prello/clean data
# Out:
# /content/drive/MyDrive/Prello/clean data

# %%
df.to_csv('clean_notary_real_estate_sales.csv', index= False)
