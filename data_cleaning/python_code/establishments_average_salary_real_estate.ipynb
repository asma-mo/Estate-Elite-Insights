# %% [markdown]
# <a href="https://colab.research.google.com/github/asma-mo/Estate-Elite-Insights/blob/afnan_branch/data_cleaning/python_code/establishments_average_salary_real_estate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import pandas as pd

# %%
from google.colab import auth
import pandas as pd
# importing numpy as np
import numpy as np

import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb

# %% [markdown]
# Load the data +Clean Data
#
# - Look at the proportion of missing data
# - Check the data type of each column
# - Dealing with Missing Values (NaN Values)
# - Check the unique values of columns
# - Dropping Columns

# %%
#Load the data

auth.authenticate_user()
project_id="data-analytics-bootcamp-363212"
data="prello"
table="POI_tourist_establishments"
query =  f"SELECT * FROM `{project_id}.{data}.{table}`"
POI_tourist_establishments=pd.read_gbq(query, project_id)
POI_tourist_establishments
# Out:
#              poi                                name   latitude  longitude  \
# 0          hotel                    Club Med (Hôtel)  45.678531  -1.163635
# 1          hotel  Cabanes des Grands Cépages (Hôtel)  44.026859   4.847491
# 2          hotel          Pierre et Vacances (Hôtel)  50.331541   1.565677
# 3          hotel           Pierre & Vacances (Hôtel)  43.285936   6.569696
# 4          hotel          Le Domaine du Golf (Hôtel)  43.541050   3.752852
# ...          ...                                 ...        ...        ...
# 26211  camp_site                   Camping municipal  45.701000   2.041247
# 26212  camp_site                   Camping municipal  46.491559   3.020672
# 26213  camp_site                   Camping municipal  45.694389   2.120544
# 26214  camp_site                   Camping municipal  45.915488   2.487122
# 26215  camp_site                   Camping municipal  43.349728  -0.262684
#
#       municipality_code  importance             name_reprocessed
# 0                 17225    0.078556                    Club Med
# 1                 84129    0.078419  Cabanes des Grands Cépages
# 2                 80333    0.077999          Pierre et Vacances
# 3                 83068    0.077702           Pierre & Vacances
# 4                 34095    0.077542          Le Domaine du Golf
# ...                 ...         ...                          ...
# 26211             19164    0.040000            Camping municipal
# 26212             03238    0.040000            Camping municipal
# 26213             19241    0.040000            Camping municipal
# 26214             23131    0.040000            Camping municipal
# 26215             64405    0.040000            Camping municipal
#
# [26216 rows x 7 columns]

# %%
#Check missing values
POI_tourist_establishments.isnull().any()
# Out:
# poi                  False
# name                 False
# latitude             False
# longitude            False
# municipality_code    False
# importance           False
# name_reprocessed     False
# dtype: bool

# %%
#Check NaN values
POI_tourist_establishments.isna().any()
# Out:
# poi                  False
# name                 False
# latitude             False
# longitude            False
# municipality_code    False
# importance           False
# name_reprocessed     False
# dtype: bool

# %%
#check duplicated values
POI_tourist_establishments.duplicated().any()
# Out:
# False

# %%
#check data type
POI_tourist_establishments.dtypes
# Out:
# poi                   object
# name                  object
# latitude             float64
# longitude            float64
# municipality_code     object
# importance           float64
# name_reprocessed      object
# dtype: object

# %%
#rename column
POI_tourist_establishments.rename(columns = {'poi':'establishments_type'}, inplace = True)

# %%
#Basic statistics
POI_tourist_establishments.describe()
# Out:
#            latitude     longitude    importance
# count  26216.000000  26216.000000  26216.000000
# mean      46.169628      2.724604      0.052033
# std        2.260598      3.120466      0.012110
# min       41.362968     -5.123231      0.030000
# 25%       44.173110      0.339955      0.043046
# 50%       45.924781      2.584392      0.050000
# 75%       48.301564      5.189572      0.063427
# max       51.081814      9.555174      0.079078

# %%
POI_tourist_establishments.to_csv("POI_tourist_establishments.csv",index=False)

# %%
#Load the data
auth.authenticate_user()
project_id="data-analytics-bootcamp-363212"
data="prello"
table="real_estate_info_by_municipality"
query =  f"SELECT * FROM `{project_id}.{data}.{table}`"
real_estate_info_by_municipality=pd.read_gbq(query, project_id)
real_estate_info_by_municipality
# Out:
#       municipality_code  intensite_tension_immo  rental_max_apartment  \
# 0                 57133                       8                 12.27
# 1                 57446                       8                 18.22
# 2                 77013                       9                 18.30
# 3                 77026                       9                 15.76
# 4                 77072                       9                 17.50
# ...                 ...                     ...                   ...
# 34436             81126                       7                 16.64
# 34437             33425                      11                 16.20
# 34438             85146                       5                 18.51
# 34439             53062                       8                 16.12
# 34440             22093                      10                 14.25
#
#        rental_min_apartment  rental_med_house  rental_max_house  \
# 0                      9.07              9.19             14.45
# 1                      7.69             10.92             14.16
# 2                      8.39             12.20             16.71
# 3                      6.28              9.51             13.20
# 4                      7.69             11.47             15.75
# ...                     ...               ...               ...
# 34436                  6.36              8.93             11.28
# 34437                  7.90             11.07             14.72
# 34438                  8.22             10.59             13.50
# 34439                  6.28              8.32             11.28
# 34440                  6.58              9.93             13.81
#
#        rental_min_house  rental_med_all  rental_max_all  rental_min_all
# 0                  6.64            9.53           13.77            7.25
# 1                  7.77           11.09           15.97            7.73
# 2                  9.21           12.26           16.75            9.19
# 3                  7.04            9.53           13.23            7.03
# 4                  8.21           11.47           15.75            8.21
# ...                 ...             ...             ...             ...
# 34436              6.45            8.93           11.28            6.45
# 34437              7.40           11.09           14.74            7.41
# 34438              8.43           10.88           15.47            8.35
# 34439              6.15            8.69           12.93            6.19
# 34440              6.51            9.80           13.94            6.53
#
# [34441 rows x 10 columns]

# %%
#Check missing values
real_estate_info_by_municipality.isnull().any()
# Out:
# municipality_code         False
# intensite_tension_immo    False
# rental_max_apartment      False
# rental_min_apartment      False
# rental_med_house           True
# rental_max_house           True
# rental_min_house           True
# rental_med_all            False
# rental_max_all            False
# rental_min_all            False
# dtype: bool

# %%
#number of missing values in each column
real_estate_info_by_municipality.isnull().sum()
# Out:
# municipality_code          0
# intensite_tension_immo     0
# rental_max_apartment       0
# rental_min_apartment       0
# rental_med_house          20
# rental_max_house          20
# rental_min_house          20
# rental_med_all             0
# rental_max_all             0
# rental_min_all             0
# dtype: int64

# %%
# filling  null value with mean of column
real_estate_info_by_municipality['rental_med_house']=real_estate_info_by_municipality['rental_med_house'].replace(to_replace = np.nan, value = real_estate_info_by_municipality['rental_med_house'].mean())

# %%
# filling  null value with mean of column
real_estate_info_by_municipality['rental_max_house']=real_estate_info_by_municipality['rental_max_house'].replace(to_replace = np.nan, value = real_estate_info_by_municipality['rental_max_house'].mean())

# %%
# filling  null value with mean of column
real_estate_info_by_municipality['rental_min_house']=real_estate_info_by_municipality['rental_min_house'].replace(to_replace = np.nan, value = real_estate_info_by_municipality['rental_min_house'].mean())

# %%
#Check NaN values
real_estate_info_by_municipality.isna().any()
# Out:
# municipality_code         False
# intensite_tension_immo    False
# rental_max_apartment      False
# rental_min_apartment      False
# rental_med_house          False
# rental_max_house          False
# rental_min_house          False
# rental_med_all            False
# rental_max_all            False
# rental_min_all            False
# dtype: bool

# %%
#check duplicated values
real_estate_info_by_municipality.duplicated().any()
# Out:
# False

# %%
#check data type
real_estate_info_by_municipality.dtypes
# Out:
# municipality_code          object
# intensite_tension_immo      Int64
# rental_max_apartment      float64
# rental_min_apartment      float64
# rental_med_house          float64
# rental_max_house          float64
# rental_min_house          float64
# rental_med_all            float64
# rental_max_all            float64
# rental_min_all            float64
# dtype: object

# %%
#rename column
real_estate_info_by_municipality.rename(columns = {'intensite_tension_immo':'demand_level'}, inplace = True)

# %%
#Basic statistics
real_estate_info_by_municipality.describe()
# Out:
#        demand_level  rental_max_apartment  rental_min_apartment  \
# count       34441.0          34441.000000          34441.000000
# mean        9.21727             15.878574              7.462678
# std        3.146829              3.555982              1.599958
# min             4.0              7.550000              4.100000
# 25%             7.0             13.620000              6.400000
# 50%             9.0             15.420000              7.130000
# 75%            11.0             17.700000              8.230000
# max            31.0             45.460000             27.810000
#
#        rental_med_house  rental_max_house  rental_min_house  rental_med_all  \
# count      34441.000000      34441.000000      34441.000000    34441.000000
# mean          10.179351         13.424505          7.375303       10.190045
# std            2.280816          3.178016          1.715943        2.213078
# min            6.040000          7.120000          3.820000        6.070000
# 25%            8.780000         11.420000          6.320000        8.790000
# 50%            9.660000         12.820000          7.010000        9.700000
# 75%           10.900000         14.490000          7.980000       10.980000
# max           29.410000         41.630000         22.550000       34.810000
#
#        rental_max_all  rental_min_all
# count    34441.000000    34441.000000
# mean        13.746826        7.355064
# std          3.348301        1.666057
# min          7.300000        3.980000
# 25%         11.600000        6.330000
# 50%         13.080000        7.000000
# 75%         15.030000        7.950000
# max         45.460000       27.810000

# %%
real_estate_info_by_municipality.to_csv("real_estate_info_by_municipality.csv",index=False)

# %%
#Load the data

auth.authenticate_user()
project_id="data-analytics-bootcamp-363212"
data="prello"
table="average_salary_by_municipality"
query =  f"SELECT * FROM `{project_id}.{data}.{table}`"
average_salary_by_municipality=pd.read_gbq(query, project_id)
average_salary_by_municipality
# Out:
#       municipality_code  avg_net_salary  year country_code
# 0                 01004    26471.026727  2019           01
# 1                 01007    26341.353419  2019           01
# 2                 01014    25897.497842  2019           01
# 3                 01024    25695.240341  2019           01
# 4                 01025    26054.712323  2019           01
# ...                 ...             ...   ...          ...
# 26670             97420    23364.247855  2015           01
# 26671             97421    19099.408481  2015           01
# 26672             97422    21854.551578  2015           01
# 26673             97423    20863.807536  2015           01
# 26674             97424    19153.252522  2015           01
#
# [26675 rows x 4 columns]

# %%
#Check missing values
average_salary_by_municipality.isnull().any()
# Out:
# municipality_code    False
# avg_net_salary       False
# year                 False
# country_code         False
# dtype: bool

# %%
#check duplicated values
average_salary_by_municipality.duplicated().any()
# Out:
# False

# %%
#check data type
average_salary_by_municipality.dtypes
# Out:
# municipality_code     object
# avg_net_salary       float64
# year                   Int64
# country_code          object
# dtype: object

# %%
average_salary_by_municipality['year'] = pd.to_datetime(average_salary_by_municipality['year'], format='%Y')
average_salary_by_municipality
# Out:
#       municipality_code  avg_net_salary       year country_code
# 0                 01004    26471.026727 2019-01-01           01
# 1                 01007    26341.353419 2019-01-01           01
# 2                 01014    25897.497842 2019-01-01           01
# 3                 01024    25695.240341 2019-01-01           01
# 4                 01025    26054.712323 2019-01-01           01
# ...                 ...             ...        ...          ...
# 26670             97420    23364.247855 2015-01-01           01
# 26671             97421    19099.408481 2015-01-01           01
# 26672             97422    21854.551578 2015-01-01           01
# 26673             97423    20863.807536 2015-01-01           01
# 26674             97424    19153.252522 2015-01-01           01
#
# [26675 rows x 4 columns]

# %%
#drop column
average_salary_by_municipality.drop('country_code', axis=1, inplace=True)

# %%
#Basic statistics
average_salary_by_municipality.describe()
# Out:
#        avg_net_salary
# count    26675.000000
# mean     25845.419949
# std       5052.783274
# min      18305.605449
# 25%      22746.156889
# 50%      24554.543298
# 75%      27374.104178
# max      85814.080997

# %%
average_salary_by_municipality.to_csv("average_salary_by_municipality.csv",index=False)
