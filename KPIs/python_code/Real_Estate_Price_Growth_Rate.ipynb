# %% [markdown]
# <a href="https://colab.research.google.com/github/asma-mo/Estate-Elite-Insights/blob/afnan_branch/KPIs/python_code/Real_Estate_Price_Growth_Rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import pandas as pd
import numpy as np
df = pd.read_csv("/content/average_salary_by_municipality (2).csv")

# %%
# we have 5 years of data
df.year.unique()
# Out:
# array(['2019-01-01', '2018-01-01', '2017-01-01', '2016-01-01',
#        '2015-01-01'], dtype=object)

# %%
df.municipality_code.value_counts()
# Out:
# 01004    5
# 01262    5
# 01384    5
# 01419    5
# 01426    5
#         ..
# 67296    1
# 01254    1
# 18180    1
# 17351    1
# 67301    1
# Name: municipality_code, Length: 5438, dtype: int64

# %%
#data for 2019
df2019 = df[(df['year'] =="2019-01-01") ]
df2019
# Out:
#      municipality_code  avg_net_salary        year
# 0                01004    26471.026727  2019-01-01
# 3595             67180    26135.560608  2019-01-01
# 3603             67218    27603.972787  2019-01-01
# 3602             67216    26855.646588  2019-01-01
# 3601             67212    29865.964709  2019-01-01
# ...                ...             ...         ...
# 1798             37245    27307.315811  2019-01-01
# 1797             37243    29843.718635  2019-01-01
# 1796             37233    24248.161315  2019-01-01
# 1795             37226    23103.733916  2019-01-01
# 1800             37261    26029.276439  2019-01-01
#
# [5395 rows x 3 columns]

# %%
#data for 2015
df2015 = df[(df['year'] =="2015-01-01") ]
df2015
# Out:
#       municipality_code  avg_net_salary        year
# 24907             67067    26195.039988  2015-01-01
# 24914             67115    24033.498256  2015-01-01
# 24913             67112    26819.606915  2015-01-01
# 24912             67106    24920.148488  2015-01-01
# 24911             67101    26400.574977  2015-01-01
# ...                 ...             ...         ...
# 23143             37243    28583.328436  2015-01-01
# 23142             37233    23026.620529  2015-01-01
# 23141             37226    21902.501667  2015-01-01
# 23140             37225    25354.557214  2015-01-01
# 26674             97424    19153.252522  2015-01-01
#
# [5295 rows x 3 columns]

# %%
# Merge the data frames based on municipality_code
merged_df = pd.merge(df2015,df2019, left_on='municipality_code', right_on='municipality_code')

merged_df
# Out:
#      municipality_code  avg_net_salary_x      year_x  avg_net_salary_y  \
# 0                67067      26195.039988  2015-01-01      27901.530735
# 1                67115      24033.498256  2015-01-01      25831.879970
# 2                67112      26819.606915  2015-01-01      29496.174533
# 3                67106      24920.148488  2015-01-01      26819.159506
# 4                67101      26400.574977  2015-01-01      28127.669788
# ...                ...               ...         ...               ...
# 5250             37243      28583.328436  2015-01-01      29843.718635
# 5251             37233      23026.620529  2015-01-01      24248.161315
# 5252             37226      21902.501667  2015-01-01      23103.733916
# 5253             37225      25354.557214  2015-01-01      26876.212729
# 5254             97424      19153.252522  2015-01-01      19620.105035
#
#           year_y
# 0     2019-01-01
# 1     2019-01-01
# 2     2019-01-01
# 3     2019-01-01
# 4     2019-01-01
# ...          ...
# 5250  2019-01-01
# 5251  2019-01-01
# 5252  2019-01-01
# 5253  2019-01-01
# 5254  2019-01-01
#
# [5255 rows x 5 columns]

# %%
#Real Estate Price Growth Rate
Growth_Rate=(merged_df['avg_net_salary_y']-merged_df['avg_net_salary_x'])/merged_df['avg_net_salary_x']
Growth_Rate=pd.DataFrame(Growth_Rate)
Growth_Rate
# Out:
#              0
# 0     0.065146
# 1     0.074828
# 2     0.099799
# 3     0.076204
# 4     0.065419
# ...        ...
# 5250  0.044095
# 5251  0.053049
# 5252  0.054845
# 5253  0.060015
# 5254  0.024375
#
# [5255 rows x 1 columns]

# %%
#  Select the columns we want to keep
merged_df['Growth_Rate']=Growth_Rate

# %%
merged_df=merged_df[['municipality_code','Growth_Rate']]
merged_df
# Out:
#      municipality_code  Growth_Rate
# 0                67067     0.065146
# 1                67115     0.074828
# 2                67112     0.099799
# 3                67106     0.076204
# 4                67101     0.065419
# ...                ...          ...
# 5250             37243     0.044095
# 5251             37233     0.053049
# 5252             37226     0.054845
# 5253             37225     0.060015
# 5254             97424     0.024375
#
# [5255 rows x 2 columns]

# %%
merged_df.to_csv("Real_Estate_Price_Growth_Rate",index=False)
