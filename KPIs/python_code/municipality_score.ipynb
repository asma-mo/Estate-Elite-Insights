# %% [markdown]
# <a href="https://colab.research.google.com/github/asma-mo/Estate-Elite-Insights/blob/afnan_branch/KPIs/python_code/municipality_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import pandas as pd

from sklearn.preprocessing import StandardScaler
ave_salary = pd.read_csv("/content/average_salary_by_municipality (3) (1).csv")
real_estate = pd.read_csv("/content/real_estate_info_by_municipality (2) (1).csv")
nb_establishments = pd.read_csv("/content/KPIs_nb_establishments_for_municipality.csv")
tourist_rate = pd.read_csv("/content/KPI_tourist_rate (2).csv")
tourist_rate1 = pd.read_csv("/content/KPI_tourist_rate (1).csv")

# %%
tourist_rate= pd.DataFrame(tourist_rate, columns=["municipality_code", "importance"])

# %% [markdown]
# Apply Standardization to all the values before calculation
# GROUP BY  municipality_code. avg(1️⃣ tourist_rate + 2️⃣ avg_net_salary- 1️⃣ nb_of_establishment+ 3️⃣ demand_level)

# %% [markdown]
# Standardization the values

# %%
# Reshape the column into a 2D array
avg_net_salary = ave_salary["avg_net_salary"].values.reshape(-1, 1)

# Fit and transform the data using the scaler
scaled_avg_net_salary = scaler.fit_transform(avg_net_salary)

# Update the dataframe with the scaled values
ave_salary["avg_net_salary"] = scaled_avg_net_salary

# %%
# Reshape the column into a 2-dimensional array
demand_level = real_estate["demand_level"].values.reshape(-1, 1)

# Fit and transform the data using the scaler
scaled_demand_level = scaler.fit_transform(demand_level)

# Update the dataframe with the scaled values
real_estate["demand_level"] = scaled_demand_level

# %%
# Reshape the column into a 2-dimensional array
nb_of_establishment = nb_establishments["poi_count"].values.reshape(-1, 1)

# Fit and transform the data using the scaler
scaled_nb_of_establishment = scaler.fit_transform(nb_of_establishment)

# Update the dataframe with the scaled values
nb_establishments["poi_count"] = scaled_nb_of_establishment

# %%
# Reshape the column into a 2-dimensional array
#tourist_rate = tourist_rate["importance"].values.reshape(-1, 1)

# Fit and transform the data using the scaler
scaled_tourist_rate  = scaler.fit_transform(tourist_rate1)

# Update the dataframe with the scaled values
tourist_rate1["importance"] = scaled_tourist_rate

# %%
tourist_rate['tourist_rate']=tourist_rate1
tourist_rate=tourist_rate.drop(['importance'], axis=1)
tourist_rate
# Out:
#      municipality_code  tourist_rate
# 0                01004     -0.257720
# 1                01005      0.556098
# 2                01007     -1.736765
# 3                01010     -0.011175
# 4                01012      1.147147
# ...                ...           ...
# 8823             95585      0.990611
# 8824             95607      0.502554
# 8825             95612     -1.736765
# 8826             95652     -1.736765
# 8827             95656     -0.695821
#
# [8828 rows x 2 columns]

# %%
ave_salary=ave_salary.drop(['year'], axis=1)
real_estate=real_estate.drop(['rental_max_apartment',	'rental_min_apartment',	'rental_med_house',	'rental_max_house',	'rental_min_house',	'rental_med_all',	'rental_max_all',	'rental_min_all'], axis=1)

# %%
 #Merge the dataframes based on 'municipality_code'
merged_df = pd.merge(ave_salary, real_estate, on='municipality_code', how='inner')
merged_df = pd.merge(merged_df, nb_establishments, on='municipality_code', how='inner')
merged_df = pd.merge(merged_df, tourist_rate, on='municipality_code', how='inner')

# %%
# Perform the calculation
merged_df['calculation'] = merged_df['tourist_rate'] + merged_df['avg_net_salary'] - merged_df['poi_count'] + merged_df['demand_level']

# Group by 'municipality_code' and calculate the average
municipality_score = merged_df.groupby(['municipality_code'],as_index=False)['calculation'].mean()
municipality_score
# Out:
#      municipality_code  calculation
# 0                01004    -0.595355
# 1                01007    -2.083192
# 2                01031     0.594589
# 3                01034    -1.757043
# 4                01043     1.962102
# ...                ...          ...
# 2964             95582    -0.091846
# 2965             95585     0.607939
# 2966             95607     1.925429
# 2967             95612    -1.153824
# 2968             95652    -0.111353
#
# [2969 rows x 2 columns]

# %%
#Export the data frame
municipality_score.to_csv("municipality_score.csv",index=False)
