# %% [markdown]
# <a href="https://colab.research.google.com/github/asma-mo/Estate-Elite-Insights/blob/najwa_branch/KPIs/python_code/Housing_stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/clean_housing_stock.csv")

# %%
df
# Out:
#        municipality_code  year  nb_principal_home  nb_second_home  \
# 0                  01339  1968                109             155
# 1                  02368  1968                132              56
# 2                  04073  1968                134              93
# 3                  04148  1968                 42              93
# 4                  05012  1968                 70              53
# ...                  ...   ...                ...             ...
# 279579             13105  2018               2951              48
# 279580             78380  2018               2325              48
# 279581             95352  2018               1918              48
# 279582             59279  2018               8137              48
# 279583             63231  2018                782              48
#
#         nb_vacants_housing  nb_tot_housing  secondary_home_rate  \
# 0                        0             264             0.587121
# ...

# %%
import pandas as pd

# Calculate the percentage and add a new column
df['occupancy_rate'] = ((df['nb_principal_home'] + df['nb_second_home'])/df['nb_tot_housing']) *100

# Display the updated DataFrame
df.tail()
# Out:
#        municipality_code  year  nb_principal_home  nb_second_home  \
# 279579             13105  2018               2951              48
# 279580             78380  2018               2325              48
# 279581             95352  2018               1918              48
# 279582             59279  2018               8137              48
# 279583             63231  2018                782              48
#
#         nb_vacants_housing  nb_tot_housing  secondary_home_rate  \
# 279579                 202            3201             0.014995
# 279580                 205            2578             0.018619
# 279581                 212            2178             0.022039
# 279582                 471            8656             0.005545
# 279583                 235            1065             0.045070
#
#         principal_home_rate  vacants_housing_rate  occupancy_rate
# 279579             0.921899              0.063105       93.689472
# ...
